# %% [markdown]
# **Project Title : *Capstone_Project*
# Initiator: *Hanan_Iftekhar***
#
# **Details:** *This notebook is specified to work on the Final Applied Data Science Capstone Project. In this project a Neighborhood Analysis will be conducted through Python Data Visualization, Analysis and Machine Learning Algorithms.*

# %% [markdown]
# **>**> **Now Let us Import Pandas Library for Loading DataFrame and other relevant Functions like Data Wrangling and Cleaning******

# %%
#Importing Pandas Library
import pandas as pd
print("The Pandas Library has been Imported for This NoteBook...")
# Out:
# The Pandas Library has been Imported for This NoteBook...

# %% [markdown]
# **> **Now Let us Import Numpy Library for Numerical Puthon function****

# %%
#Importning Numpy Library 
import numpy as np
print("The Numpy Library has been Imported for This Notebook...")
# Out:
# The Numpy Library has been Imported for This Notebook...

# %%
#Let us print the statement now
print("Hello Capstone Project Course!")
